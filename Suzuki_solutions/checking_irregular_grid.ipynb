# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np


sys.path.append('../Numerical_methods')
from bachelor_funcs import get_1_dev_new, Σ_initial, r_array

# %%
len(r_array),
# Out:
# 205

# %%
t = np.array([1, 3, 5, 6, 9])
t_d = np.diff(t)
t_d
# Out:
# array([2, 2, 1, 3])

# %%
plt.plot(r_array[:-1], np.diff(r_array))

# %%
x = np.linspace(0, 4*np.pi)
plt.plot(r_array, np.sin(r_array))
plt.plot(x, np.sin(x))

dev_1 = get_1_dev_new(r_array, np.diff(r_array))
plt.xlim(0, 4*np.pi)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1548/1712434223.py in <module>
#       3 plt.plot(x, np.sin(x))
#       4
# ----> 5 dev_1 = get_1_dev_new(r_array, np.diff(r_array))
#       6 plt.xlim(0, 4*np.pi)
#
# c:\Users\chris\Documents\KU - Fysik\6. Semester\Bachelor\Code\Suzuki_solutions\../Numerical_methods\bachelor_funcs.py in get_1_dev_new(array, Δx)
#      21     array_dev[0] = (forward_backward(3, 1, forward = True)[0] @ (array[:3] / Δx[:3]))
#      22     array_dev[-1] = forward_backward(3, 1, forward = False)[0] @ (array[-3:] / Δx[-3:])
# ---> 23     array_dev[1: -1] = central(4, 1)[0] @ np.array([array[:-2] / Δx[:-2] , array[1: -1] / Δx[1 : -1], array[2:] / Δx[2:]])
#      24     return array_dev
#      25
#
# ValueError: operands could not be broadcast together with shapes (203,) (202,)
