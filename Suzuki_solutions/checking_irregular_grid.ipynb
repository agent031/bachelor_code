# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np


sys.path.append('../Numerical_methods')
from bachelor_funcs import get_1_dev_new, Σ_initial, r_array, first_dev_matrix
from ODE_schemes import stencil_calc 
from scheme_calculator import *

# %%
len(r_array),
# Out:
# (205,)

# %%
t = np.array([1, 3, 5, 6, 9])
t_d = np.diff(t)
t_d
# Out:
# array([2, 2, 1, 3])

# %%
plt.plot(r_array[:-1], np.diff(r_array))

# %%
N = len(r_array)
s = 3

i1 = 0
i2 = s
x = np.arange(205)
A = np.zeros((N, N))
for i in range(N):
    if abs(i1 - i) >= s/2 and i2 < N:
        i1 += 1
        i2 += 1

    stencil = x[i1:i2] - x[i]
    coeff = stencil_calc(stencil, 1)
    A[i, i1:i2] = coeff

# %%
r_dev1 = first_dev_matrix @ np.sin(r_array)

# %%
x = np.linspace(0, 4*np.pi)
plt.plot(r_array, np.sin(r_array))
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.plot(r_array, r_dev1)


plt.xlim(0, 4*np.pi)
# Out:
# (0.0, 12.566370614359172)
